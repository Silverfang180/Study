# %%
#Tuple
"""tup1=(2,5,8,1,7)

position = 2

output = (2,8,1,7)"""

# %%
tup1=(2,5,8,1,7)

remove = 5
tup1[0:1] + tup1[2:]
# Out:
# (2, 8, 1, 7)

# %%
tup1=(2,5,8,1,7)
remove=int(input("Enter the number to remove:"))
tup1[0:remove-1] + tup1[remove:]
# Out:
# Enter the number to remove:4
# (2, 5, 8, 7)

# %% [markdown]
# **SETS**
# - set is an unordered collection of heterogeneous data types values.
# - Set doesn't support indexing and slicing
# - Set is mutable in nature. But, we can't modify the element and we can add new element or remove existing element.
# - Set doesn't allow duplicate elements.
# - Set element enclosed in {} and separated by commas --> **,**
#
# - In sets TRUE --> 1, FALSE --> 0

# %%
set1={1,3,'choma', 'faizal', None, 'zeros', 0, False}
set1
# Out:
# {0, 1, 3, None, 'choma', 'faizal', 'zeros'}

# %%
#Addition
set1={1,3,'choma', 'faizal', None, 'zeros', 0, False}
set1.add(5)
set1
# Out:
# {0, 1, 3, 5, None, 'choma', 'faizal', 'zeros'}

# %%
#Update:- in update operation multiple elements can be added into set

set1.update('Abhishke','faizal')
set1
# Out:
# {' ',
#  0,
#  1,
#  3,
#  5,
#  'A',
#  None,
#  '_',
#  'a',
#  'b',
#  'e',
#  'f',
#  'h',
#  'i',
#  'k',
#  'l',
#  'm',
#  'o',
#  'r',
#  's',
#  't',
#  'z',
#  'zeros'}

# %%
# Remove

set1.remove('choma')

# %%
set1
# Out:
# {0, 1, 3, 5, None, 'faizal', 'zeros'}

# %%
# Discard
set1.discard('faizal')

# %%
set1
# Out:
# {' ',
#  0,
#  1,
#  3,
#  5,
#  'A',
#  None,
#  '_',
#  'a',
#  'b',
#  'e',
#  'f',
#  'h',
#  'i',
#  'k',
#  'l',
#  'm',
#  'o',
#  'r',
#  's',
#  't',
#  'z',
#  'zeros'}

# %% [markdown]
# # **Dictionary**
# - Dictionary is an ordered collections of Key-value pairs structures .
# - Dictionary doesn't allow indexing and slicing. But, here key is used as indexing  .
# - it is mutable in nature .
# - it doesn't allow duplicate keys .
# - it is enclosed in {} and in key-value pairs .

# %%
report={"Name":"Rocky bhai", "greetings":"salam rocky bhai"}
print(report)
# Out:
# {'Name': 'Rocky bhai', 'greetings': 'salam rocky bhai'}

# %%
report['Name']
# Out:
# 'Rocky bhai'

# %%
report = {'name':["Faizal", 'Abhisehek','Nigga'], 'Marks':[90,90,90,]}# IN single key we ca add multiple values with the help of list
report
# Out:
# {'name': ['Faizal', 'Abhisehek', 'Nigga'], 'Marks': [90, 90, 90]}

# %%
report = {'name':("Faizal", 'Abhisehek','Nigga'), 'Marks':(90,90,90,)}# To retrive an perticular element from list in dictionary we specify index
report["name"][1], report['Marks'][2]
# Out:
# ('Abhisehek', 90)

# %%
report.update({'name':['Abhi','Abhishek','Faizal']})
report
# Out:
# {'name': ['Abhi', 'Abhishek', 'Faizal'], 'Marks': (90, 90, 90)}

# %%
report = {'name':("Faizal", 'Abhisehek','Nigga'), 'Marks':(90,90,90,)}
report.pop('name')
report
# Out:
# {'Marks': (90, 90, 90)}

# %%
report = {'name':("Faizal", 'Abhisehek','Nigga'), 'Marks':(90,90,90,)}
report.popitem()
report
# Out:
# {'name': ('Faizal', 'Abhisehek', 'Nigga')}

# %%
text = "hello world 2"
text1={}
for i in text:
  if i in text1:
    text1[i]+=1
  else:
    text1[i] = 1
text1
# Out:
# {'h': 1, 'e': 1, 'l': 3, 'o': 2, ' ': 2, 'w': 1, 'r': 1, 'd': 1, '2': 1}

# %%
for i in range(1,3):
  for j in range(7,9):
    print(j,i)
# Out:
# 7 1
# 8 1
# 7 2
# 8 2

# %% [markdown]
# **LOOPS**
# - For loop
# - While loop
# - Nested loop

# %%
# for loop is
for i in "Hello":
  print(i)
# Out:
# H
# e
# l
# l
# o

# %%
for i in '*':
  for j in range(1,5):
    print(i*j)
# Out:
# *
# **
# ***
# ****

# %%
for i in '&':
  for j in range(1,9):
    print(i*j)
# Out:
# &
# &&
# &&&
# &&&&
# &&&&&
# &&&&&&
# &&&&&&&
# &&&&&&&&

# %%
for i in range (0,5):
  for j in '@':
    print(i*j)
# Out:
# @
# @@
# @@@
# @@@@

# %%
for i in range(4):
  for j in range(i+1):
    print('A', end = ' ')
  print()
# Out:
# A
# A A
# A A A
# A A A A

# %%
for i in range(5):
  for j in range(1,i+1):
    print(i, end=' ')
  print()
# Out:
# 1
# 2 2
# 3 3 3
# 4 4 4 4

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  if x == "banana":
    continue

  print(x)
# Out:
# apple
# cherry

# %%
lst=[23,55,6,8,13,11,90,22,97,64,28]
even=[]
odd=[]
for i in lst:
  if i %2==0:
    even.append(i)
  else:
    odd.append(i)
print(even)
print(odd)
# Out:
# [6, 8, 90, 22, 64, 28]
# [23, 55, 13, 11, 97]

# %%
fees = ['$30','$40','$30','$20']
sum=0
for i in fees:
    i=int(i.replace('$',''))
    sum +=i
print(f"${sum} fees bhar de bhai 120$ hi hai pagar nhi aai hai ab tak")
# Out:
# $120 fees bhar de bhai 120$ hi hai pagar nhi aai hai ab tak
