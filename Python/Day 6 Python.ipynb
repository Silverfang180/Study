# %% [markdown]
# #**Continution of Day 5**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Employees.csv')# retrive dataset
df.head(5)
# Out:
#    Id              Name  Age  Base Pay  OverTime Pay  Benefits  \
# 0   1   Marcia Stephens   22    120000       60000.0   15000.0
# 1   2       Karen Lopez   22    120000       60000.0   15000.0
# 2   3    Heather Reilly   22     60000       30000.0    7500.0
# 3   4     Cindy Leblanc   32     70000       35000.0    8750.0
# 4   5  Colin Richardson   22    120000       60000.0   15000.0
#
#    Total Pay benefits Loan Department  Duration  Rating  \
# 0            195000.0   No        SDE         7     8.2
# 1            195000.0   No      SDE-T         6     9.3
# 2             97500.0   No        SDE         5     6.6
# 3            113750.0   No      Admin         1     8.0
# 4            195000.0  Yes        SDE         3     5.7
#
#                             Email         State Country
# 0  ['marcia.stephens@reddit.com']      colarado     USA
# 1       ['karen.lopez@gmail.com']         taxes     USA
# 2  ['heather.reilly@hotmail.com']  NewBrunswick  Canada
# ...

# %%
# Which Country Emplpoyees has more rating?
# Solution 1 with detailed info.
df[(df['Rating']>7)&df['Country']]
# Out:
#        Id               Name  Age  Base Pay  OverTime Pay  Benefits  \
# 0       1    Marcia Stephens   22    120000       60000.0   15000.0
# 1       2        Karen Lopez   22    120000       60000.0   15000.0
# 3       4      Cindy Leblanc   32     70000       35000.0    8750.0
# 6       7         David Ward   43     90000       45000.0   11250.0
# 7       8     Yvonne Johnson   22    120000       60000.0   15000.0
# ..    ...                ...  ...       ...           ...       ...
# 992   993         Eric Mason   27     96000       48000.0   12000.0
# 995   996    Douglas English   32    110000       55000.0   13750.0
# 996   997     Michael Berger   27    120000       60000.0   15000.0
# 997   998  Theodore Robinson   22     96000       48000.0   12000.0
# 999  1000    Katherine Keith   30     96000       48000.0   12000.0
#
#      Total Pay benefits Loan Department  Duration  Rating  \
# 0              195000.0   No        SDE         7     8.2
# ...

# %%
#Solution 2 which is correct way to represent
df.groupby('Country')['Rating'].mean().sort_values()
# Out:
# Country
# USA               7.713139
# Canada            7.870683
# Russia            7.948571
# United Kingdom    7.991379
# Name: Rating, dtype: float64

# %%
# Country which has highest employees rating
df.groupby('Country')['Rating'].mean().sort_values(ascending=False)[:1]
# Out:
# Country
# United Kingdom    7.991379
# Name: Rating, dtype: float64

# %%
# If we want to visualize the data
df.groupby('Country')['Rating'].mean().sort_values(ascending=False).plot(kind='pie')
# Out:
# <Axes: ylabel='Rating'>

# %%
# If we want to visualize the data
df.groupby('Country')['Rating'].mean().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Country'>

# %%
# List 3 states based on rating
df.groupby('State')['Rating'].mean().sort_values(ascending=True)[:3]
# Out:
# State
# taxes      7.390000
# utah       7.428261
# Alberta    7.548077
# Name: Rating, dtype: float64

# %%
df.groupby('State')['Rating'].mean().sort_values(ascending=False).plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Number of employees who has loan them?
df['Loan'].value_counts().plot(kind='bar')
plt.title('Number of Loans')
plt.xlabel('Loan')
plt.ylabel('Employees Counts')
# Out:
# Text(0, 0.5, 'Employees Counts')
